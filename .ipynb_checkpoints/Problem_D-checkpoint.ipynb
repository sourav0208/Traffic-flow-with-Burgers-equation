# %% [markdown]
# # Problem D: Prediction of Traffic Flow based on Burgers’ Equation Model
#
# Burgers' equation is a classical PDE model that captures the interplay between nonlinear convection and diffusion, making it well-suited for describing traffic flow dynamics. In this context, the convective term models the tendency for traffic to compress as vehicle density increases, while the diffusive term reflects the smoothing effect of individual driver reactions to surrounding traffic conditions.
#
# The viscous Burgers' equation governing the evolution of vehicle velocity is:
#
# $$
# u_t + uu_x = \nu u_{xx}, \qquad x\in(-1,1),\ t\in(0,1] \tag{3}
# $$
#
# where:
# - $u(x,t)$: vehicle velocity field (m/s),
# - $\nu = 0.1/\pi$: kinematic viscosity coefficient (a higher value reflects more cautious, diffusive driver behavior),
# - $x$: position along the road segment,
# - $t$: time.
#
# Homogeneous Dirichlet boundary conditions are imposed at both ends of the road:
#
# $$
# u(-1,\, t) = u(1,\, t) = 0, \qquad t \in (0, 1]
# $$
#
# Given an initial velocity profile $u(x, 0) = a(x)$, the full spatio-temporal velocity field $u(x,t)$ for $t > 0$ is uniquely determined by solving Eq. (3). In practice, however, running a high-fidelity finite difference solver for every new initial condition is computationally prohibitive. The goal of this task is therefore to learn a fast surrogate that approximates the solution operator $a(x) \mapsto u(x,t)$.
#
# ## Task: predicting the velocity filed $u(x,t)$ given the inital field $a(x)$
#
# A dataset of initial conditions $a(x)$ sampled from a distribution $\mathcal{A}$ has been collected, along with the corresponding velocity fields $u(x,t)$ computed by a high-precision Finite Difference Method (FDM) solver. The dataset is **partially labeled**: only a small subset of initial conditions is paired with its FDM solution, while a much larger set of initial conditions has no corresponding solution available. This reflects a realistic scenario in which high-fidelity simulation data is scarce and expensive to obtain. The trained surrogate model should accurately predict $u(x,t)$ for any new initial condition $a(x)$ drawn from the same distribution $\mathcal{A}$, at negligible computational cost.
#
# ### Goals
#
# - Select a suitable deep learning method for this task and justify your choice.
# - Report your implementation setup, including network architecture, activation function, optimizer (with learning rate), number of epochs, batch size, loss formulation, and any additional techniques used for improvement.
# - Compute the $L^2$ relative error on the **test dataset** at each training epoch and plot the `Error vs. Epoch` curve (reporting the final error). The error is defined as:
#
# $$
# \text{error} = \frac{1}{N}\sum_{j=1}^{N}\sqrt{\frac{\displaystyle\sum_i\left|u^{(j)}_{\text{pred}}(x_i,t_i)-u^{(j)}_{\text{true}}(x_i,t_i)\right|^2}{\displaystyle\sum_i\left|u^{(j)}_{\text{true}}(x_i,t_i)\right|^2}}
# $$
#
# where $j$ indexes the sample and $i$ indexes the spatio-temporal grid point.
#
# - For the **first test instance**, use `matplotlib` to produce four separate figures:
#   1. The initial condition $a(x) = u(x, 0)$
#   2. The predicted velocity field $u_{\text{pred}}(x,t)$
#   3. The ground truth velocity field $u_{\text{true}}(x,t)$
#   4. The pointwise absolute error $|u_{\text{pred}} - u_{\text{true}}|$
#
# ### Dataset
#
# All data are provided in `ProblemD_dataset.h5`:
#
# | Key | Shape | Description |
# |---|---|---|
# | `a_train_labeled` | (200, 256) | $N=200$ **labeled** initial fields, sampled at 256 spatial sensors |
# | `u_train_labeled` | (200, 200, 256) | Corresponding FDM-computed velocity fields on a $200\times256$ spatio-temporal grid |
# | `a_train_unlabeled` | (1800, 256) | $N=1800$ **unlabeled** initial fields (no paired solution available) |
# | `a_test` | (200, 256) | Test initial conditions (**do not use for training**) |
# | `u_test` | (200, 200, 256) | Ground truth velocity fields for test instances (**do not use for training**) |
# | `x_mesh` | (256, 1) | Spatial coordinates of the 256 grid points |
# | `t_mesh` | (200, 1) | Temporal coordinates of the 200 time steps |
#
# > 📥 Dataset download: [https://www.kaggle.com/datasets/yhzang32/dno4pdes](https://www.kaggle.com/datasets/yhzang32/dno4pdes)

# %%
import numpy as np
import h5py
import torch
import matplotlib.pyplot as plt
dtype = torch.float32
######################################
# Load training data
######################################
with h5py.File('ProblemD_dataset.h5', 'r') as file:
    print(file.keys())
    t_mesh = torch.tensor(np.array(file['t_mesh']), dtype=dtype)
    x_mesh = torch.tensor(np.array(file['x_mesh']), dtype=dtype)
    a_test = torch.tensor(np.array(file['a_test']), dtype=dtype)
    u_test = torch.tensor(np.array(file['u_test']), dtype=dtype)
    a_train_labeled = torch.tensor(np.array(file['a_train_labeled']), dtype=dtype)
    u_train_labeled = torch.tensor(np.array(file['u_train_labeled']), dtype=dtype)
    a_train_unlabeled = torch.tensor(np.array(file['a_train_unlabeled']), dtype=dtype)
    #
    X, T = np.meshgrid(x_mesh, t_mesh)
#
print('t_mesh:', t_mesh.shape, 'x_mesh:', x_mesh.shape)

print('a_train_labeled:', a_train_labeled.shape, 'u_train_labeled:', u_train_labeled.shape)
print('a_train_unlabeled:', a_train_unlabeled.shape)
print('a_test:', a_test.shape, 'u_test:', u_test.shape)
#################################
inx = 0
fig, axes = plt.subplots(1,2, figsize=(16,4))
#
cntr = axes[0].plot(x_mesh, a_train_labeled[0])
axes[0].set_title('The initial field a(x)')
#
cntr = axes[1].contourf(T, X, u_train_labeled[inx])
axes[1].set_title('The velocity field u(t,x)')
plt.colorbar(cntr)
#
plt.show()
# Out:
# <KeysViewHDF5 ['a_test', 'a_train_labeled', 'a_train_unlabeled', 't_mesh', 'u_test', 'u_train_labeled', 'x_mesh']>
# t_mesh: torch.Size([200, 1]) x_mesh: torch.Size([256, 1])
# a_train_labeled: torch.Size([200, 256]) u_train_labeled: torch.Size([200, 200, 256])
# a_train_unlabeled: torch.Size([1800, 256])
# a_test: torch.Size([200, 256]) u_test: torch.Size([200, 200, 256])

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
def setup_seed(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    np.random.seed(seed)
    torch.backends.cudnn.deterministic = True

setup_seed(3407)

device = 'cuda'
dtype = torch.float32

N_t = 200
N_x = 256
data_train = h5py.File('ProblemD_dataset.h5', 'r')
# Out:
# cuda

# %%
def get_data(data, ndata=200):


    a = np.array(data["a_train_labeled"][:ndata])
    u = np.array(data["u_train_labeled"][:ndata])

    x1 = np.array(data['x_mesh']).reshape(-1)
    t1 = np.array(data['t_mesh']).reshape(-1)

    x_grid, t_grid = np.meshgrid(x1, t1)
    mesh = np.stack([x_grid, t_grid], axis=-1 )
    gridx = mesh.reshape(1,N_t,N_x,2)
    a = torch.tensor(a,dtype=dtype).reshape(ndata, 1,N_x, 1).repeat(1, N_t,1,1)
    x = torch.tensor(gridx,dtype=dtype).repeat( ndata,1,1,1)
    u = torch.tensor(u, dtype=dtype).reshape(ndata,N_t, N_x, 1)
    ax = torch.cat( [a, x],dim=-1)

    return ax, u, gridx.reshape(-1, 2)


ax_train, u_train, gridx = get_data(data_train,ndata=200)
ax_train = ax_train.to(device)
u_train = u_train.to(device)
coordinate_grid = torch.tensor( gridx.reshape( 1,N_t, N_x, 2),dtype=dtype).to(device)
print('ax_train:', ax_train.shape, ax_train.device)
print('u_train:', u_train.shape, u_train.device)
print('gridx:', gridx.shape)
print('a_train_unlabeled:', a_train_unlabeled.shape)
print('a_test:', a_test.shape)
print('u_test:', u_test.shape)
print('coordinate_grid:', coordinate_grid.shape)
# Out:
# ax_train: torch.Size([200, 200, 256, 3]) cuda:0
# u_train: torch.Size([200, 200, 256, 1]) cuda:0
# gridx: (51200, 2)
# a_train_unlabeled: torch.Size([1800, 256])
# a_test: torch.Size([200, 256])
# u_test: torch.Size([200, 200, 256])
# coordinate_grid: torch.Size([1, 200, 256, 2])

# %%
import torch.nn as nn

class SpectralConv2d(nn.Module):
    def __init__(self, in_size, out_size, modes1, modes2, dtype):
        super(SpectralConv2d, self).__init__()
        self.in_size = in_size 
        self.out_size = out_size 
        self.modes1 = modes1
        self.modes2 = modes2 
        self.scale = 1./(in_size * out_size)

        if (dtype is None) or (dtype == torch.float32):
            ctype = torch.complex64 
        elif (dtype == torch.float64):
            ctype = torch.complex128 
        else:
            raise TypeError(f'No such data type.')

        self.weight1 = nn.Parameter(self.scale * torch.rand(in_size,out_size,modes1, modes2,dtype=ctype))
        self.weight2 = nn.Parameter(self.scale * torch.rand(in_size,out_size,modes1, modes2,dtype=ctype))

    def compl_mul_2d(self, input, weights):
        return torch.einsum('bixy,ioxy->boxy', input, weights)

    def forward(self, x):
         
         batch_size = x.shape[0]
         x_ft = torch.fft.rfft2(x)
         out_ft = torch.zeros(batch_size,self.out_size,x.size(-2),x.size(-1)//2 + 1,device=x.device,dtype=torch.cfloat)
         out_ft[:, :, :self.modes1, :self.modes2] = self.compl_mul_2d(x_ft[:, :, :self.modes1, :self.modes2],self.weight1)
         out_ft[:, :, -self.modes1:, :self.modes2] = self.compl_mul_2d(x_ft[:, :, -self.modes1:, :self.modes2],self.weight2)
         x = torch.fft.irfft2(out_ft,s=(x.size(-2), x.size(-1)))

         return x

class FNO2d(nn.Module):
    
    def __init__(self, in_size:int, out_size:int, modes1:int, modes2:int, hidden_list:list[int], dtype=None):
        super(FNO2d, self).__init__()
        self.hidden_list = hidden_list         
        self.activation = nn.ReLU()
        self.fc_in = nn.Linear(in_size, hidden_list[0], dtype=dtype)
        conv_net, w_net = [], []
        self.hidden_in = hidden_list[0]
    
        for hidden in hidden_list[1:]:
            conv_net.append(SpectralConv2d(self.hidden_in, hidden, modes1, modes2, dtype))
            w_net.append(nn.Conv1d(self.hidden_in, hidden, 1, dtype=dtype))
            self.hidden_in =  hidden

        self.spectral_conv = nn.Sequential(*conv_net)
        self.weight_conv = nn.Sequential(*w_net)

        self.fc_out0 = nn.Linear(self.hidden_in, 128, dtype=dtype)
        self.fc_out1 = nn.Linear(128, out_size, dtype=dtype)
    
    def forward(self, ax):
        
        batch_size = ax.shape[0]
        mx_size, my_size = ax.shape[1], ax.shape[2]
        ax = self.fc_in(ax)
        ax = ax.permute(0, 3, 1, 2)

        hidden_last = self.hidden_list[0] 
        for conv, weight, hidden_size in zip(self.spectral_conv, self.weight_conv, self.hidden_list[1:]):
            ax1 = conv(ax)  
            ax2 = weight(ax.view(batch_size, hidden_last, -1)).view(batch_size, hidden_size, mx_size, my_size)
            ax = self.activation(ax1 + ax2)
            hidden_las = hidden_size 
        
        ax = ax.permute(0, 2, 3, 1)
        ax = self.fc_out0(ax)
        ax = self.activation(ax)

        return self.fc_out1(ax)

mode1 = 8
mode2 = 8
hidden_list = [40, 40, 40]
model_u = FNO2d(ax_train.shape[-1], u_train.shape[-1], mode1, mode2, hidden_list).to(device)

total_trainable_params = sum(p.numel() for p in model_u.parameters() if p.requires_grad)
print(f'{total_trainable_params:,} training parameters.')
# Out:
# 418,417 training parameters.

# %%
class UnitGaussianNormalizer:
    def __init__(self, ax, eps=1e-8):
        self.mean = torch.mean(ax[..., 0:1], 0)
        self.std  = torch.std( ax[..., 0:1], 0)
        self.eps  = eps

    def encode(self, ax):
        d = ax.shape[-1] - 1
        a_norm, x_part = torch.split(ax, [1, d], dim=-1)
        return torch.cat([(a_norm - self.mean) / (self.std + self.eps), x_part], dim=-1)

    def decode(self, ax):
        d = ax.shape[-1] - 1
        a_norm, x_part = torch.split(ax, [1, d], dim=-1)
        return torch.cat([a_norm * (self.std + self.eps) + self.mean, x_part], dim=-1)

normalizer_ax = UnitGaussianNormalizer(ax_train.to(device))

class mollifier(object):

    def __init__(self):
        super(mollifier, self).__init__()

    def __call__(self, u, ax):
        a_mesh = ax[..., 0:1]
        x_mesh = ax[..., 1:2]
        t_mesh = ax[..., 2:3]

        u = (a_mesh + t_mesh * (1.0 - x_mesh**2)* u)

        return u

# %%
class LossClass(object):

    def __init__(self, u_model, lambda_r=1.0, lambda_d=1.0):
        self.u_model = u_model
        self.mollifier = mollifier()
        self.lambda_r = lambda_r
        self.lambda_d = lambda_d

        self.dt = 1.0 / (N_t - 1)
        self.dx = 2.0 / (N_x - 1)

        self.nu = 0.1 / np.pi

    def _predict(self, ax_batch):
        ax_norm    = normalizer_ax.encode(ax_batch)
        u_pred = self.u_model(ax_norm)
        u_pred = self.mollifier(u_pred, ax_batch)
        return u_pred[..., 0]  

    def loss_pde(self, ax_batch):
        n_batch = ax_batch.shape[0]
        u = self._predict(ax_batch)

        u_t = (u[:, 2:, 1:-1] - u[:, :-2, 1:-1]) / (2.0 * self.dt)
        u_x = (u[:, 1:-1, 2:] - u[:, 1:-1, :-2]) / (2.0 * self.dx)
        u_xx = (u[:, 1:-1, 2:] - 2.0 * u[:, 1:-1, 1:-1] +  u[:, 1:-1, :-2]) / (self.dx**2)
        u_center = u[:,1:-1, 1:-1]

        residual = (u_t + u_center * u_x- self.nu * u_xx)

        left = residual.reshape( n_batch, -1)
        right = torch.zeros_like(left)
        loss = torch.norm(left - right, p=2, dim=1)

        return torch.mean(loss)

    def loss_data(self, ax_batch, u_batch):
        batch_size = u_batch.shape[0]
        u_pred     = self._predict(ax_batch)       
        u_true     = u_batch[..., 0]
        loss = torch.norm((u_true - u_pred).reshape(batch_size, -1), 2, dim=1)
        return torch.mean(loss)

    def loss_total(self, ax_batch, u_batch=None):
        loss = self.lambda_r  * self.loss_pde(ax_batch)
        if self.lambda_d > 0 and u_batch is not None:
            loss = loss + self.lambda_d * self.loss_data(ax_batch, u_batch)
        return loss

    def get_error(self, ax, u):
        
        batch_size = u.shape[0]
        u_pred = self._predict(ax)                    
        u_true = u[..., 0] 
        nomi = torch.norm((u_true - u_pred).reshape(batch_size, -1), 2, dim=1)
        domi = torch.norm( u_true.reshape(batch_size, -1), 2, dim=1)
        error  = nomi/domi
        return torch.mean(error)

# %%
from torch.utils.data import Dataset, DataLoader

class MyDataset(Dataset):

    def __init__(self, ax, u):
        self.ax = ax
        self.u = u

    def __getitem__(self, index):
        return self.ax[index], self.u[index]

    def __len__(self):
        return self.ax.shape[0]

# %%
batch_size_labeled = 10
batch_size_unlabeled = 10
batch_size_test = 10

labeled_dataset = MyDataset(ax_train, u_train)
labeled_loader = DataLoader( labeled_dataset, batch_size=batch_size_labeled, shuffle=True)
unlabeled_loader = DataLoader(a_train_unlabeled, batch_size=batch_size_unlabeled,shuffle=True)

# %%
n_test = a_test.shape[0]
print("Raw a_test:", a_test.shape)
print("Raw u_test:", u_test.shape)
a_test_grid = a_test.reshape( n_test, 1, N_x, 1).repeat( 1,N_t, 1,1)
#coordinate_test = ax_train[0:1,:,:, 1:3].detach().cpu().repeat(n_test, 1, 1,1)
coordinate_test = torch.tensor(gridx.reshape(1, N_t, N_x, 2), dtype=dtype).repeat(n_test, 1, 1, 1)
ax_test = torch.cat([a_test_grid, coordinate_test],dim=-1)

test_dataset = MyDataset(ax_test, u_test)
test_loader = DataLoader( test_dataset, batch_size=batch_size_test,shuffle=False)
u_test = u_test.reshape( n_test, N_t, N_x, 1)
print("ax_test:", ax_test.shape)
print("u_test:", u_test.shape)
# Out:
# Raw a_test: torch.Size([200, 256])
# Raw u_test: torch.Size([200, 200, 256])
# ax_test: torch.Size([200, 200, 256, 3])
# u_test: torch.Size([200, 200, 256, 1])

# %%
print( "no.lab bat:", len(labeled_loader))

print("no. unlab batc:", len(unlabeled_loader))
# Out:
# no.lab bat: 20
# no. unlab batc: 180

# %%
LAMBDA_R = 0.02
LAMBDA_D = 1.0
lossClass = LossClass(u_model=model_u, lambda_r=LAMBDA_R,lambda_d=LAMBDA_D)
epochs = 300
lr = 1e-3
optimizer = torch.optim.Adam(model_u.parameters(), lr=lr, weight_decay=1e-4)
scheduler = torch.optim.lr_scheduler.StepLR( optimizer, step_size=np.int32(epochs / 5), gamma=0.5)

# %%
from pathlib import Path
from datetime import datetime
import json
import csv
def create_experiment_dir(base_dir="experiments", name="burgers_pino"):
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    exp_dir = Path(base_dir) / f"{name}_{timestamp}"
    exp_dir.mkdir(parents=True, exist_ok=True)

    (exp_dir / "figures").mkdir(exist_ok=True)
    (exp_dir / "checkpoints").mkdir(exist_ok=True)
    (exp_dir / "arrays").mkdir(exist_ok=True)

    return exp_dir

exp_dir = create_experiment_dir(name="burgers_pino")
print("Saving experiment to:", exp_dir)
# Out:
# Saving experiment to: experiments\burgers_pino_20260714_230055

# %%
metrics_path = exp_dir / "metrics.csv"

with open(metrics_path, "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(["epoch", "total_loss", "labeled_loss", "unlabeled_pde_loss", "l2_error", "learning_rate"])

# %%
best_error = float("inf")
best_epoch = None
best_total_loss = None
best_labeled_loss = None
best_unlabeled_loss = None

loss_list = []
labeled_loss_list = []
unlabeled_loss_list = []
error_list = []

# %%
print("Before training:")
print("epochs =", epochs)
print("loss_list length =", len(loss_list))
print("labeled_loss_list length =", len(labeled_loss_list))
print("unlabeled_loss_list length =", len(unlabeled_loss_list))
print("error_list length =", len(error_list))
# Out:
# Before training:
# epochs = 300
# loss_list length = 0
# labeled_loss_list length = 0
# unlabeled_loss_list length = 0
# error_list length = 0

# %%
print("CUDA available:", torch.cuda.is_available())
print("GPU:", torch.cuda.get_device_name(0))
print("Model device:", next(model_u.parameters()).device)
print("Allocated memory:", torch.cuda.memory_allocated() / 1024**3, "GB")
print("Reserved memory:", torch.cuda.memory_reserved() / 1024**3, "GB")
# Out:
# CUDA available: True
# GPU: NVIDIA GeForce RTX 5060 Laptop GPU
# Model device: cuda:0
# Allocated memory: 0.15814638137817383 GB
# Reserved memory: 0.158203125 GB

# %%
import time
from tqdm import trange

t0 = time.time()

for epoch in trange(epochs):

    model_u.train()

    epoch_loss = 0.0
    epoch_labeled_loss = 0.0
    epoch_unlabeled_loss = 0.0

    labeled_iterator = iter(labeled_loader)

    for unlabeled_batch in unlabeled_loader:
        #print(type(unlabeled_batch))
        #print(unlabeled_batch.shape)
        try:

            labeled_batch = next(labeled_iterator)

        except StopIteration:

            labeled_iterator = iter( labeled_loader)

            labeled_batch = next( labeled_iterator)

        ax_labeled_batch = labeled_batch[0].to(device)
        u_labeled_batch = labeled_batch[1].to(device)
        #a_unlabeled_batch = unlabeled_batch[0].to(device)
        a_unlabeled_batch = unlabeled_batch.to(device)
        #print("ax_unlabelled batch shape:", a_unlabeled_batch.shape)
        current_batch_size = a_unlabeled_batch.shape[0]
        a_unlabeled_grid = a_unlabeled_batch.reshape( current_batch_size, 1,N_x, 1).repeat(1, N_t, 1, 1)
        coordinate_batch = coordinate_grid.repeat(current_batch_size, 1,1,1)
        ax_unlabeled_batch = torch.cat( [a_unlabeled_grid, coordinate_batch], dim=-1)
        loss_labeled = lossClass.loss_total(ax_labeled_batch, u_labeled_batch)
        loss_unlabeled = lossClass.loss_total(ax_unlabeled_batch)
        loss_train = (loss_labeled + loss_unlabeled)
        
        optimizer.zero_grad()
        loss_train.backward()
        torch.nn.utils.clip_grad_norm_( model_u.parameters(), max_norm=1.0)
        optimizer.step()
        epoch_loss += loss_train.item()

        epoch_labeled_loss += (loss_labeled.item())
        epoch_unlabeled_loss += (loss_unlabeled.item())
    scheduler.step()
    number_batches = len(unlabeled_loader)

    epoch_loss /= number_batches

    epoch_labeled_loss /= number_batches

    epoch_unlabeled_loss /= number_batches


    #loss_list.append(epoch_loss)

    #labeled_loss_list.append(epoch_labeled_loss)

    #unlabeled_loss_list.append(epoch_unlabeled_loss)
    
    model_u.eval()

    epoch_test_error = 0.0
    number_test_samples = 0.0

    with torch.no_grad():
        for ax_test_batch, u_test_batch in test_loader:
            ax_test_batch = ax_test_batch.to(device)
            u_test_batch = u_test_batch.to(device)

            u_pred_batch = lossClass._predict(ax_test_batch)
            #print("u_pred_bt shape", u_pred_batch.shape)
            u_true_batch = u_test_batch

            current_test_batch_size = u_true_batch.shape[0]

            nomi = torch.norm((u_true_batch - u_pred_batch).reshape(current_test_batch_size, -1), p=2, dim=1)
            domi = torch.norm(u_true_batch.reshape(current_test_batch_size, -1), p=2, dim=1)
            rel_err = nomi / domi

            epoch_test_error += rel_err.sum().item()
            number_test_samples += current_test_batch_size

    error = epoch_test_error / number_test_samples
    error_list.append(error)
    loss_list.append(epoch_loss)
    labeled_loss_list.append(epoch_labeled_loss)
    unlabeled_loss_list.append(epoch_unlabeled_loss)
    
    if error < best_error:
        best_error = error
        best_epoch = epoch + 1
        best_total_loss = epoch_loss
        best_labeled_loss = epoch_labeled_loss
        best_unlabeled_loss = epoch_unlabeled_loss

        torch.save(
            {
                "epoch": epoch + 1,
                "model_state_dict": model_u.state_dict(),
                "optimizer_state_dict": optimizer.state_dict(),
                "scheduler_state_dict": scheduler.state_dict(),
                "total_loss": epoch_loss,
                "labeled_loss": epoch_labeled_loss,
                "unlabeled_pde_loss": epoch_unlabeled_loss,
                "l2_error": error
            },exp_dir / "best_model.pt")

    
    if (epoch + 1) % 50 == 0:
        print(f"Epoch {epoch + 1:4d} | Total loss: {epoch_loss:.4e} | Labeled loss: {epoch_labeled_loss:.4e} | Unlabeled PDE loss:{epoch_unlabeled_loss:.4e}")

    current_lr = optimizer.param_groups[0]["lr"]

    with open(metrics_path, "a", newline="") as f:
        writer = csv.writer(f)
        writer.writerow([epoch + 1, epoch_loss, epoch_labeled_loss, epoch_unlabeled_loss, epoch_test_error, current_lr])


print( f"\nTotal training time: {time.time() - t0:.1f} s")
error_array = np.array(error_list)
loss_array = np.array(loss_list)
labeled_loss_array = np.array(labeled_loss_list)
unlabeled_loss_array = np.array(unlabeled_loss_list)

best_index = int(np.argmin(error_array))
print("Best epoch:", best_index + 1)
print("Best L2 error:", error_array[best_index])
print("Total loss at best epoch:", loss_array[best_index])
print("Labeled loss at best epoch:", labeled_loss_array[best_index])
print("Unlabeled PDE loss at best epoch:", unlabeled_loss_array[best_index])
print("Final L2 error:", error_array[-1])
print("Final total loss:", loss_array[-1])
print("Final labeled loss:", labeled_loss_array[-1])
print("Final unlabeled PDE loss:", unlabeled_loss_array[-1])
# Out:
#  17%|██████████████████████▏                                                                                                              | 50/300 [32:22<2:41:28, 38.75s/it]
# Epoch   50 | Total loss: 5.1939e+00 | Labeled loss: 3.2403e+00 | Unlabeled PDE loss:1.9536e+00
#  33%|███████████████████████████████████████████▎                                                                                      | 100/300 [1:03:31<2:08:07, 38.44s/it]
# Epoch  100 | Total loss: 5.2378e+00 | Labeled loss: 3.0592e+00 | Unlabeled PDE loss:2.1786e+00
#  50%|█████████████████████████████████████████████████████████████████                                                                 | 150/300 [1:35:13<1:30:54, 36.36s/it]
# Epoch  150 | Total loss: 4.1357e+00 | Labeled loss: 2.4471e+00 | Unlabeled PDE loss:1.6886e+00
#  67%|██████████████████████████████████████████████████████████████████████████████████████▋                                           | 200/300 [2:07:29<1:05:46, 39.46s/it]
# ...

# %%
print("CUDA available:", torch.cuda.is_available())
print("GPU:", torch.cuda.get_device_name(0))
print("Model device:", next(model_u.parameters()).device)
print("Allocated memory:", torch.cuda.memory_allocated() / 1024**3, "GB")
print("Reserved memory:", torch.cuda.memory_reserved() / 1024**3, "GB")
# Out:
# CUDA available: True
# GPU: NVIDIA GeForce RTX 5060 Laptop GPU
# Model device: cuda:0
# Allocated memory: 0.2130270004272461 GB
# Reserved memory: 2.861328125 GB

# %%
print('ax_test:', ax_test.shape)
print('u_test:', u_test.shape)
# Out:
# ax_test: torch.Size([200, 200, 256, 3])
# u_test: torch.Size([200, 200, 256, 1])

# %%
model_u.eval()

prediction_list = []

with torch.no_grad():
    for ax_test_batch, u_test_batch in test_loader:
        ax_test_batch = ax_test_batch.to(device)
        u_pred_batch = lossClass._predict(ax_test_batch)
        prediction_list.append(u_pred_batch.cpu())

u_pred_all = torch.cat(prediction_list, dim=0)

print("u_pred_all shape:", u_pred_all.shape)
# Out:
# u_pred_all shape: torch.Size([200, 200, 256])

# %%
config = {
    "N_t": N_t,
    "N_x": N_x,
    "epochs": epochs,
    "lr": lr,
    "modes1": mode1,
    "modes2": mode2,
    "hidden_list": hidden_list,
    "lambda_r": LAMBDA_R,
    "lambda_d": LAMBDA_D,
    "batch_size_labeled": batch_size_labeled,
    "batch_size_unlabeled": batch_size_unlabeled,
    "optimizer": "Adam"
    
}

with open(exp_dir / "config.json", "w") as f:
    json.dump(config, f, indent=4)

# %%
best_epoch_data = {
    "Best epoch": best_index + 1,
    "Best L2 error":error_array[best_index],
    "Total loss at best epoch": loss_array[best_index],
    "Labeled loss at best epoch": labeled_loss_array[best_index],
    "Unlabeled PDE loss at best epoch": unlabeled_loss_array[best_index],
    "Final L2 error": error_array[-1],
    "Final total loss":loss_array[-1],
    "Final labeled loss": labeled_loss_array[-1],
    "Final unlabeled PDE loss": unlabeled_loss_array[-1]
}
with open(exp_dir / "best_epoch_data.json", "w") as f:
    json.dump(best_epoch_data, f, indent=4)

# %%
torch.save(
    {
        "model_state_dict": model_u.state_dict(),
        "optimizer_state_dict": optimizer.state_dict(),
        "scheduler_state_dict": scheduler.state_dict(),
        "config": config,
        "loss_list": loss_list,
        "error_list": error_list,
    },
    exp_dir / "checkpoints" / "final_model.pt"
)

# %%
best_model_path = exp_dir / "best_model.pt"

checkpoint = torch.load(best_model_path, map_location=device, weights_only=False)
model_u.load_state_dict(checkpoint["model_state_dict"])
model_u.eval()

print("Loaded best model from epoch:", checkpoint["epoch"])
print("Best L2:", checkpoint["l2_error"])
# Out:
# Loaded best model from epoch: 296
# Best L2: 0.03004500925540924

# %%
print(len(unlabeled_loss_list))
# Out:
# 300

# %%
sample_idx = 0
epoch_axis = np.arange(1, epochs + 1)
a_show = ax_test[sample_idx, 0, :, 0].numpy()
u_true_show = u_test[sample_idx, :, :, 0].numpy()
u_pred_show = u_pred_all[sample_idx, :, :].numpy()

absolute_error_show = np.abs(u_true_show - u_pred_show)

x_plot = ax_test[sample_idx, 0, :, 1].numpy()
t_plot = ax_test[sample_idx, :, 0, 2].numpy()


fig, axs = plt.subplots(1, 4, figsize=(18, 4))
axs[0].plot(x_plot, a_show)
axs[0].set_title('Initial cond. a(x)')
axs[0].set_xlabel('x')
axs[0].set_ylabel('u')

true_plot = axs[1].contourf(x_plot, t_plot, u_true_show, levels=40, cmap='jet')
fig.colorbar(true_plot, ax=axs[1])
axs[1].set_title('True u(x,t)')
axs[1].set_xlabel('x')
axs[1].set_ylabel('t')

prediction_plot = axs[2].contourf(x_plot, t_plot, u_pred_show, levels=40, cmap='jet')
fig.colorbar(prediction_plot, ax=axs[2])
axs[2].set_title('Predicted u(x,t)')
axs[2].set_xlabel('x')
axs[2].set_ylabel('t')

error_plot = axs[3].contourf(x_plot, t_plot, absolute_error_show, levels=40, cmap='jet')
fig.colorbar(error_plot, ax=axs[3])
axs[3].set_title('Abs. error')
axs[3].set_xlabel('x')
axs[3].set_ylabel('t')
plt.tight_layout()
fig.savefig(exp_dir / "figures" / "prediction_comparison.png", dpi=300, bbox_inches="tight")
plt.show()

fig, axs = plt.subplots(1, 3, figsize=(15, 4))
axs[0].semilogy(epoch_axis,loss_list)
axs[0].set_title('total train loss')
axs[0].set_xlabel('epoch')

axs[1].semilogy(epoch_axis,labeled_loss_list)
axs[1].set_title('labelled loss')
axs[1].set_xlabel('epochs')

axs[2].semilogy(epoch_axis,unlabeled_loss_list)
axs[2].set_title('unlabeled PDE loss')
axs[2].set_xlabel('epoch')

plt.tight_layout()
fig.savefig(exp_dir / "figures" / "training_curves.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
# I Noticed list accumulation. plotting again. otherwise need to train again. it took me 161 min for 300 epochs
# found--> appending two times.

# %%
'''epochs_current_run = epochs
epoch_axis = np.arange(1, epochs_current_run + 1)

loss_current = loss_list[-epochs_current_run:]
labeled_current = labeled_loss_list[-epochs_current_run:]
unlabeled_current = unlabeled_loss_list[-epochs_current_run:]

fig, axs = plt.subplots(1, 3, figsize=(15, 4))

axs[0].semilogy(epoch_axis, loss_current)
axs[0].set_title("Total training loss")
axs[0].set_xlabel("Epoch")
axs[0].set_ylabel("Loss")

axs[1].semilogy(epoch_axis, labeled_current)
axs[1].set_title("Labeled loss")
axs[1].set_xlabel("Epoch")
axs[1].set_ylabel("Loss")

axs[2].semilogy(epoch_axis, unlabeled_current)
axs[2].set_title("Unlabeled PDE loss")
axs[2].set_xlabel("Epoch")
axs[2].set_ylabel("Loss")

plt.tight_layout()
fig.savefig(exp_dir / "figures" / "training_curves_300_epochs.png", dpi=300, bbox_inches="tight")
plt.show()'''
# Out:
# 'epochs_current_run = epochs\nepoch_axis = np.arange(1, epochs_current_run + 1)\n\nloss_current = loss_list[-epochs_current_run:]\nlabeled_current = labeled_loss_list[-epochs_current_run:]\nunlabeled_current = unlabeled_loss_list[-epochs_current_run:]\n\nfig, axs = plt.subplots(1, 3, figsize=(15, 4))\n\naxs[0].semilogy(epoch_axis, loss_current)\naxs[0].set_title("Total training loss")\naxs[0].set_xlabel("Epoch")\naxs[0].set_ylabel("Loss")\n\naxs[1].semilogy(epoch_axis, labeled_current)\naxs[1].set_title("Labeled loss")\naxs[1].set_xlabel("Epoch")\naxs[1].set_ylabel("Loss")\n\naxs[2].semilogy(epoch_axis, unlabeled_current)\naxs[2].set_title("Unlabeled PDE loss")\naxs[2].set_xlabel("Epoch")\naxs[2].set_ylabel("Loss")\n\nplt.tight_layout()\nfig.savefig(exp_dir / "figures" / "training_curves_300_epochs.png", dpi=300, bbox_inches="tight")\nplt.show()'

# %%
epoch_axis = np.arange(1, len(error_list) + 1)

plt.figure(figsize=(6, 4))
plt.semilogy(epoch_axis, error_list)
plt.xlabel("Epoch")
plt.ylabel("rel L2 error")
plt.title("val. relative L2 error")
plt.tight_layout()
plt.savefig(exp_dir / "figures" / "l2_error_curve.png", dpi=300, bbox_inches="tight")
plt.show()
